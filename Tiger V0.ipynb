# %%
import os
from jira_data_fetcher import JiraDataFetcher
from crewai import Agent, Task, Crew
import pandas as pd

# %%
fetcher = JiraDataFetcher()

# %%
# Fetch and save weekly data
project_id = "14130"
labels = ["roadmap-mr-program-2025"]
issues_data = fetcher.get_weekly_jira_data(project_id, labels, limit=2)

# %%
week_number = fetcher.save_weekly_data(issues_data)
